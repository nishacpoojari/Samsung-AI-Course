# %%
import numpy as np

np.__version__

arr1 = np.array([1,3,5,7,9])
arr2 = np.array([1,3,5,7,9])
type(arr1)

print(id(arr1))
print(id(arr2))
arr1 = arr2
print("Address of array 1:",id(arr1))
print("Address of array 2:",id(arr2))

arr3 = np.copy(arr1)
print(arr3)
print(id(arr3))

#help(np.copy)

type((1,2,3,4))
np.array((1,2,3,4))

type({"one":1, "two":2,"three":3})
np.array({"one":1, "two":2,"three":3})
# Out:
# 1584236502480
# 1584236497104
# Address of array 1: 1584236497104
# Address of array 2: 1584236497104
# [1 3 5 7 9]
# 1584236502192
# array({'one': 1, 'two': 2, 'three': 3}, dtype=object)
