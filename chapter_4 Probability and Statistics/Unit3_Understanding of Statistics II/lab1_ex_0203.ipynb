# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

# %%
print(os.listdir('/content/drive/MyDrive'))

# %%
df=pd.read_csv('data-studentlist.csv',header='infer')

# %%
df.shape

# %%
df.head(5)

# %%
df['height'].mean()

# %%
df['height'].var(ddof=1)

# %%
df['height'].std(ddof=1)

# %%
df['height'].mean()

# %%
df['height'].median()

# %%
df['height'].quantile(0,1)

# %%
df['height'].quantile(0,1)

# %% [markdown]
# Boxplot

# %%
IQR = df['height'].quantile(0.75).df['height']
